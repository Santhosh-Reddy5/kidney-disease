# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1W9ErSzP6-dzTUGieyEJQwuLLnqLmhZwk/view?usp=drive_link"

# %%
file_id=url.split("/")[-2]

# %%
file_id
# Out:
# '1W9ErSzP6-dzTUGieyEJQwuLLnqLmhZwk'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "kidney.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1W9ErSzP6-dzTUGieyEJQwuLLnqLmhZwk
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1W9ErSzP6-dzTUGieyEJQwuLLnqLmhZwk&confirm=t&uuid=529e467c-e94d-4ae5-8fa9-b98d7157fbcb
# To: /Users/santhoshreddy/Downloads/projects/kidney-disease/research/kidney.zip
# 100%|██████████| 943M/943M [00:30<00:00, 31.3MB/s]
# 'kidney.zip'
